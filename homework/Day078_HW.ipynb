# %% [markdown]
# ## Work
# 1. 請嘗試將 preproc_x 替換成以每筆資料的 min/max 進行標準化至 -1 ~ 1 間，再進行訓練
# 2. 請嘗試將 mlp 疊更深 (e.g 5~10 層)，進行訓練後觀察 learning curve 的走勢
# 3. (optional) 請改用 GPU 進行訓練 (如果你有 GPU 的話)，比較使用 CPU 與 GPU 的訓練速度

# %%
## 確認硬體資源
"""
Your code here
"""
# Out:
# '\nYour code here\n'

# %%
import os
import keras

# Try to enable GPU (optional)
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 31s 0us/step

# %%
## 資料前處理
"""
Your code here
"""
def preproc_x(x, flatten=True):
    x = x.reshape(len(x), -1)
    x = 2 * ((x - x.min(axis = 0)) / (x.max(axis = 0) - x.min(axis  = 0))) - 1
    return x

#def preproc_y():
#    pass

def preproc_y(y, num_classes = 10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
train, test = keras.datasets.cifar10.load_data()

x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
"""
Your code here
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128, 64, 32]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 32)                2080
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,748,266
# Trainable params: 1,748,266
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 超參數設定
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 256

# %%
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# %%
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.7268 - acc: 0.3884 - val_loss: 1.5406 - val_acc: 0.4617
# Epoch 2/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.4867 - acc: 0.4744 - val_loss: 1.4628 - val_acc: 0.4913
# Epoch 3/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.3669 - acc: 0.5186 - val_loss: 1.4082 - val_acc: 0.5054
# Epoch 4/100
# 50000/50000 [==============================] - 14s 279us/step - loss: 1.2740 - acc: 0.5531 - val_loss: 1.4150 - val_acc: 0.5077
# Epoch 5/100
# 50000/50000 [==============================] - 14s 276us/step - loss: 1.1854 - acc: 0.5828 - val_loss: 1.3811 - val_acc: 0.5179
# Epoch 6/100
# 50000/50000 [==============================] - 14s 278us/step - loss: 1.1096 - acc: 0.6097 - val_loss: 1.3543 - val_acc: 0.5299
# Epoch 7/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 1.0320 - acc: 0.6353 - val_loss: 1.3665 - val_acc: 0.5406
# Epoch 8/100
# 50000/50000 [==============================] - 14s 287us/step - loss: 0.9654 - acc: 0.6602 - val_loss: 1.3895 - val_acc: 0.5360
# Epoch 9/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.9002 - acc: 0.6822 - val_loss: 1.4167 - val_acc: 0.5329
# Epoch 10/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 0.8254 - acc: 0.7071 - val_loss: 1.4765 - val_acc: 0.5301
# Epoch 11/100
# 50000/50000 [==============================] - 14s 278us/step - loss: 0.7604 - acc: 0.7325 - val_loss: 1.4918 - val_acc: 0.5349
# Epoch 12/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 0.7047 - acc: 0.7500 - val_loss: 1.5388 - val_acc: 0.5350
# Epoch 13/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.6422 - acc: 0.7756 - val_loss: 1.6457 - val_acc: 0.5353
# Epoch 14/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.5865 - acc: 0.7920 - val_loss: 1.7091 - val_acc: 0.5352
# Epoch 15/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.5440 - acc: 0.8075 - val_loss: 1.7516 - val_acc: 0.5391
# Epoch 16/100
# 50000/50000 [==============================] - 13s 270us/step - loss: 0.4920 - acc: 0.8264 - val_loss: 1.8361 - val_acc: 0.5347
# Epoch 17/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 0.4451 - acc: 0.8423 - val_loss: 1.9382 - val_acc: 0.5385
# Epoch 18/100
# 50000/50000 [==============================] - 14s 271us/step - loss: 0.4186 - acc: 0.8524 - val_loss: 2.0646 - val_acc: 0.5305
# Epoch 19/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.3807 - acc: 0.8670 - val_loss: 2.1287 - val_acc: 0.5267
# Epoch 20/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.3605 - acc: 0.8742 - val_loss: 2.1759 - val_acc: 0.5272
# Epoch 21/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.3327 - acc: 0.8840 - val_loss: 2.3146 - val_acc: 0.5277
# Epoch 22/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.3058 - acc: 0.8936 - val_loss: 2.3156 - val_acc: 0.5204
# Epoch 23/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.2720 - acc: 0.9032 - val_loss: 2.4491 - val_acc: 0.5354
# Epoch 24/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.2628 - acc: 0.9070 - val_loss: 2.5325 - val_acc: 0.5331
# Epoch 25/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.2472 - acc: 0.9141 - val_loss: 2.6442 - val_acc: 0.5261
# Epoch 26/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.2451 - acc: 0.9158 - val_loss: 2.7284 - val_acc: 0.5288
# Epoch 27/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 0.2323 - acc: 0.9200 - val_loss: 2.7744 - val_acc: 0.5266
# Epoch 28/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.2283 - acc: 0.9207 - val_loss: 2.7895 - val_acc: 0.5201
# Epoch 29/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.2143 - acc: 0.9263 - val_loss: 2.8947 - val_acc: 0.5230
# Epoch 30/100
# 50000/50000 [==============================] - 14s 276us/step - loss: 0.1825 - acc: 0.9373 - val_loss: 2.9043 - val_acc: 0.5247
# Epoch 31/100
# 50000/50000 [==============================] - 14s 281us/step - loss: 0.1819 - acc: 0.9367 - val_loss: 3.0237 - val_acc: 0.5189
# Epoch 32/100
# 50000/50000 [==============================] - 14s 277us/step - loss: 0.2046 - acc: 0.9296 - val_loss: 2.9530 - val_acc: 0.5317
# Epoch 33/100
# 50000/50000 [==============================] - 14s 276us/step - loss: 0.1753 - acc: 0.9391 - val_loss: 3.0207 - val_acc: 0.5333
# Epoch 34/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.1739 - acc: 0.9401 - val_loss: 3.1625 - val_acc: 0.5259
# Epoch 35/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.1661 - acc: 0.9432 - val_loss: 3.0950 - val_acc: 0.5303
# Epoch 36/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.1450 - acc: 0.9503 - val_loss: 3.2638 - val_acc: 0.5283
# Epoch 37/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.1629 - acc: 0.9434 - val_loss: 3.1653 - val_acc: 0.5225
# Epoch 38/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.1511 - acc: 0.9480 - val_loss: 3.2312 - val_acc: 0.5332
# Epoch 39/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.1510 - acc: 0.9492 - val_loss: 3.2912 - val_acc: 0.5289
# Epoch 40/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 0.1533 - acc: 0.9481 - val_loss: 3.2879 - val_acc: 0.5318
# Epoch 41/100
# 50000/50000 [==============================] - 13s 269us/step - loss: 0.1276 - acc: 0.9569 - val_loss: 3.3409 - val_acc: 0.5304
# Epoch 42/100
# 50000/50000 [==============================] - 13s 269us/step - loss: 0.1493 - acc: 0.9490 - val_loss: 3.3827 - val_acc: 0.5330
# Epoch 43/100
# 50000/50000 [==============================] - 14s 271us/step - loss: 0.1117 - acc: 0.9619 - val_loss: 3.4479 - val_acc: 0.5373
# Epoch 44/100
# 50000/50000 [==============================] - 14s 271us/step - loss: 0.1156 - acc: 0.9600 - val_loss: 3.6014 - val_acc: 0.5305
# Epoch 45/100
# 50000/50000 [==============================] - 13s 269us/step - loss: 0.1547 - acc: 0.9473 - val_loss: 3.4168 - val_acc: 0.5291
# Epoch 46/100
# 50000/50000 [==============================] - 14s 270us/step - loss: 0.1311 - acc: 0.9566 - val_loss: 3.4597 - val_acc: 0.5282
# Epoch 47/100
# 50000/50000 [==============================] - 13s 269us/step - loss: 0
100
# 50000/50000 [==============================] - 14s 271us/step - loss: 0.0709 - acc: 0.9771 - val_loss: 3.9189 - val_acc: 0.5270
# Epoch 80/100
# 50000/50000 [==============================] - 13s 268us/step - loss: 0.0831 - acc: 0.9725 - val_loss: 3.8656 - val_acc: 0.5272
# Epoch 81/100
# 50000/50000 [==============================] - 14s 271us/step - loss: 0.0763 - acc: 0.9755 - val_loss: 3.9402 - val_acc: 0.5291
# Epoch 82/100
# 50000/50000 [==============================] - 13s 269us/step - loss: 0.0887 - acc: 0.9714 - val_loss: 3.7852 - val_acc: 0.5269
# Epoch 83/100
# 50000/50000 [==============================] - 13s 268us/step - loss: 0.0660 - acc: 0.9787 - val_loss: 3.9243 - val_acc: 0.5385
# Epoch 84/100
# 50000/50000 [==============================] - 13s 267us/step - loss: 0.0764 - acc: 0.9758 - val_loss: 3.9449 - val_acc: 0.5271
# Epoch 85/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.0705 - acc: 0.9770 - val_loss: 3.9513 - val_acc: 0.5274
# Epoch 86/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.0657 - acc: 0.9786 - val_loss: 4.0018 - val_acc: 0.5269
# Epoch 87/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.0753 - acc: 0.9764 - val_loss: 3.9363 - val_acc: 0.5303
# Epoch 88/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 0.0800 - acc: 0.9746 - val_loss: 3.9076 - val_acc: 0.5323
# Epoch 89/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.0889 - acc: 0.9723 - val_loss: 3.9178 - val_acc: 0.5184
# Epoch 90/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.0784 - acc: 0.9746 - val_loss: 3.8778 - val_acc: 0.5271
# Epoch 91/100
# 50000/50000 [==============================] - 14s 273us/step - loss: 0.0654 - acc: 0.9789 - val_loss: 3.9313 - val_acc: 0.5315
# Epoch 92/100
# 50000/50000 [==============================] - 13s 268us/step - loss: 0.0636 - acc: 0.9797 - val_loss: 4.0085 - val_acc: 0.5259
# Epoch 93/100
# 50000/50000 [==============================] - 13s 268us/step - loss: 0.0547 - acc: 0.9824 - val_loss: 4.0597 - val_acc: 0.5287
# Epoch 94/100
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.0477 - acc: 0.9844 - val_loss: 4.0079 - val_acc: 0.5300
# Epoch 95/100
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.0773 - acc: 0.9760 - val_loss: 4.0548 - val_acc: 0.5283
# Epoch 96/100
# 50000/50000 [==============================] - 13s 269us/step - loss: 0.0779 - acc: 0.9745 - val_loss: 3.9824 - val_acc: 0.5315
# Epoch 97/100
# 50000/50000 [==============================] - 14s 270us/step - loss: 0.0765 - acc: 0.9752 - val_loss: 3.9961 - val_acc: 0.5292
# Epoch 98/100
# 50000/50000 [==============================] - 13s 269us/step - loss: 0.0559 - acc: 0.9821 - val_loss: 4.1311 - val_acc: 0.5311
# Epoch 99/100
# 50000/50000 [==============================] - 14s 279us/step - loss: 0.0748 - acc: 0.9758 - val_loss: 4.0209 - val_acc: 0.5290
# Epoch 100/100
# 50000/50000 [==============================] - 14s 274us/step - loss: 0.0541 - acc: 0.9823 - val_loss: 4.0111 - val_acc: 0.5352

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
