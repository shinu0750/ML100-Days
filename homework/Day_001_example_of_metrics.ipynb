# %% [markdown]
# # 統計指標實作範例
# ## 常見於迴歸問題的評估指標
# * Mean Absolute Error (MAE)
# * Mean Squared Error (MSE)
#
# ## 常見於分類問題的指標
# * Binary Cross Entropy (CE)
#
# ##### 後面的課程還會有更詳細的說明

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.865

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
# HW3
def MeanSquareError(y):
    mse = (sum((y - MAE) ** 2)) / len(y)
    return mse

MSE = MeanSquareError(y)
print("The Mean Square Error is %3.f" % (MSE))
# Out:
# The Mean Square Error is 27157

# %% [markdown]
# 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# ATP Matches, 1968 to 2017
# https://www.kaggle.com/sijovm/atpdata
#
# 1. 你選的這組資料為何重要
#     整理與分析後的數據可以用來當作觀戰指標。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     雖然上面沒有說明資料從何而來，但可以推測是從官網上一筆一筆資料收集下來的，而這些資料是由比賽時的紀錄員所記錄的。
#
# 3. 蒐集而來的資料型態為何
#     為結構化的資料，分別為字串、時間、與數值所構成的。
#
# 4. 這組資料想解決的問題如何評估
#     問題如：某球員在盤數0-2落後下的狀況，有多少機會追回三盤並贏得比賽。
#     評估方法：先找到某球員的全部數據，接著找出打過五盤的比賽，接著分輸二贏三的場次佔了多少，另外針對兩方球員的對戰紀錄納入為另一個參數同時進行評估。

# %% [markdown]
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     如何提升稼動率
#     因為當每台車的空車時間縮短，表示有更多的客戶，當有更多的客戶就有更多的收入。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     1.從每台車的乘車紀錄中，計算每位客人的乘車時間，每位客人之間的空閒時間。
#     2.每台車的行車導航之行車紀錄(GPS)。
#     3.地圖，包含當地景點與地標...等等。
#     4.各大眾交通之時刻表與即時動態。
#     5.每台車的行車紀錄器(影像)。
#
# 3. 蒐集而來的資料型態為何
#     字串、時間、數值、地圖、圖像。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     針對每台車的GPS進行分析，例如到火車站時，再透過影像的行車紀錄，判斷潛在客人的多寡，其他車隊的車的多寡，或者透過GPS了解是否同時間安排過多車輛在同一點，導致客源不足供應，而使得總載客數減少。
